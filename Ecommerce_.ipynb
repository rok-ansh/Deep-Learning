# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("OnlineRetail.csv", encoding = 'latin-1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 197727    553931     71053                  WHITE METAL LANTERN         8
# 197728    553931        C2                             CARRIAGE         1
# 197729    553932     22617           BAKING SET SPACEBOY DESIGN         3
# 197730    553932     22138        BAKING SET 9 PIECE RETROSPOT          3
# 197731    553932     21704              BAG 250g SWIRLY MARBLES        12
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
pip install mlxtend

# %%
df['InvoiceNo'].value_counts()
# Out:
# 537434     675
# 538071     652
# 538349     620
# 537638     601
# 537237     597
#           ...
# 540549       1
# 544348       1
# 550608       1
# C550609      1
# 539638       1
# Name: InvoiceNo, Length: 10084, dtype: int64

# %%
import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# InvoiceNo          0
# StockCode          0
# Description      784
# Quantity           0
# InvoiceDate        0
# UnitPrice          1
# CustomerID     57861
# Country            1
# dtype: int64

# %%
df.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197732 entries, 0 to 197731
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    197732 non-null  object
#  1   StockCode    197732 non-null  object
#  2   Description  196948 non-null  object
#  3   Quantity     197732 non-null  int64
#  4   InvoiceDate  197732 non-null  object
#  5   UnitPrice    197731 non-null  float64
#  6   CustomerID   139871 non-null  float64
#  7   Country      197731 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 12.1+ MB

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 197727    553931     71053                  WHITE METAL LANTERN         8
# ...

# %%
# To remove the extra space after the sentence - strip()
df['Description']=df['Description'].str.strip()
df.dropna(axis = 0, subset = 'InvoiceNo', inplace = True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
# This is to remove any extra character in invoice eg C580480
df = df[~df['InvoiceNo'].str.contains('C')]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194168 entries, 0 to 197731
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    194168 non-null  object
#  1   StockCode    194168 non-null  object
#  2   Description  193384 non-null  object
#  3   Quantity     194168 non-null  int64
#  4   InvoiceDate  194168 non-null  object
#  5   UnitPrice    194167 non-null  float64
#  6   CustomerID   136497 non-null  float64
#  7   Country      194167 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 13.3+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# To see the wole data
# pd.set_option('display.max_rows', 532621)
# pd.set_option('display.max_columns', 8)
# pd.set_option('display.width', 10000)

# %%
# Lets create a basket based on Invoice customer buyed a product

basket = (df[df['Country'] == 'France'].groupby(['InvoiceNo','Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)).set_index('InvoiceNo')

# %%
basket

# %%
basket.shape

# %%
# Now for association Rule
# !pip install apyori

# %%
from apyori import apriori

transactions = [
    ['beer', 'nuts'],
    ['beer', 'cheese'],
]
results = list(apriori(transactions))

# %%
data = pd.read_csv("Market_Basket_Optimisation.csv")

# %%
data
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
data = pd.read_csv("Market_Basket_Optimisation.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
transaction = []
for i in range(0,7500):
    transaction.append([str(data.values[i,j]) for j in range(0,20)])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
transaction
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...
